# %% [markdown]
# Convert .json to .csv

# %%
from zipfile import ZipFile
comments = "/content/jsonbyline.zip"

with ZipFile(comments, 'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
import os
import json

def readJson(folder_path):
    data = []
    for filename in os.listdir(folder_path):
        if filename.endswith("_jsonbyline.txt"):
            filepath = os.path.join(folder_path, filename)
            with open(filepath, "r") as file:
                jsonFile = file.readlines()
                for line in jsonFile:
                    data.append(json.loads(line))
    return data

folder_path = "/content/jsonbyline"
data = readJson(folder_path)

# %%
import pandas as pd
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#                     commentId  \
# 0  UgwDiX-hqefp0iTKMv14AaABAg
# 1  Ugw062F8z99NTWMey3p4AaABAg
# 2  Ugxl_ynU-Ci5sMF2pGB4AaABAg
# 3  UgyaOJEZsVTRvGstV-B4AaABAg
# 4  Ugyl6CvXSlt6LpiPDpV4AaABAg
#
#                                                 text
# 0  UPSC IAS (Pre + Mains) Live Foundation Batch 1...
# 1                                 Thanks for sharing
# 2  Even public is not aware about the effect on h...
# 3                                   Super analysis 👍
# 4             सरकार को इन चीजों से कोई मतलब नहीं है।

# %%
# download this file
df.to_csv('NEWSComments.csv', index=False)

# %%
df.describe()
# Out:
#                          commentId                  text
# count                        74231                 74231
# unique                       74231                 69054
# top     UgwDiX-hqefp0iTKMv14AaABAg  I will question more
# freq                             1                  1686
