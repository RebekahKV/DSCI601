# %% [markdown]
# Convert .json to .csv

# %%
from zipfile import ZipFile
comments = "/content/jsonbyline.zip"

with ZipFile(comments, 'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
import os
import json

def readJson(folder_path):
    data = []
    for filename in os.listdir(folder_path):
        if filename.endswith("_jsonbyline.txt"):
            filepath = os.path.join(folder_path, filename)
            with open(filepath, "r") as file:
                jsonFile = file.readlines()
                for line in jsonFile:
                    data.append(json.loads(line))
    return data

folder_path = "/content/jsonbyline"
data = readJson(folder_path)

# %%
import pandas as pd
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#                     commentId  \
# 0  Ugy3A-tuNdqYABNyZ914AaABAg
# 1  Ugx3fs6hobNaz6t9gCZ4AaABAg
# 2  UgzYy-gPaWKGSFKjnjp4AaABAg
# 3  UgxiIFuYEw1_eeW6v6F4AaABAg
# 4  Ugx9BB0w1J_ph-Ud5FN4AaABAg
#
#                                                 text
# 0                                              Gadha
# 1  Sare dogs agar barat Jaiynge To pate kaun chatega
# 2                                              Right
# 3                                    Chal chutiye...
# 4                                        Politics 😀😀

# %%
# download this file
df.to_csv('Comments.csv', index=False)

# %%
df.describe()
# Out:
#                          commentId                  text
# count                        84450                 84450
# unique                       84450                 78776
# top     Ugy3A-tuNdqYABNyZ914AaABAg  I will question more
# freq                             1                  1686
